# %%
import numpy as np
import pandas as pd


import re
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from sklearn.feature_extraction.text import TfidfVectorizer

#models:
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\vanshika\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
df=pd.read_csv('Day4_Fake_News_Data.csv')

# %%
df.head()
# Out:
#    id                                              title              author
# 0   0  House Dem Aide: We Didn’t Even See Comey’s Let...       Darrell Lucus  \
# 1   1  FLYNN: Hillary Clinton, Big Woman on Campus - ...     Daniel J. Flynn
# 2   2                  Why the Truth Might Get You Fired  Consortiumnews.com
# 3   3  15 Civilians Killed In Single US Airstrike Hav...     Jessica Purkiss
# 4   4  Iranian woman jailed for fictional unpublished...      Howard Portnoy
#
#                                                 text  label
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...      1
# 1  Ever get the feeling your life circles the rou...      0
# 2  Why the Truth Might Get You Fired October 29, ...      1
# 3  Videos 15 Civilians Killed In Single US Airstr...      1
# 4  Print \nAn Iranian woman has been sentenced to...      1

# %%
numerical_feature =[feature for feature in df.columns if df[feature].dtype!='O']
categorical_feature =[feature for feature in df.columns if df[feature].dtype=='O']

# %%
df['label'].value_counts()
# Out:
# label
# 1    10413
# 0    10387
# Name: count, dtype: int64

# %%
df=df.fillna('') #replacing null with empty string

# %%
df['content']=df['author']+' '+df['title']

# %%
df.head()
# Out:
#    id                                              title              author
# 0   0  House Dem Aide: We Didn’t Even See Comey’s Let...       Darrell Lucus  \
# 1   1  FLYNN: Hillary Clinton, Big Woman on Campus - ...     Daniel J. Flynn
# 2   2                  Why the Truth Might Get You Fired  Consortiumnews.com
# 3   3  15 Civilians Killed In Single US Airstrike Hav...     Jessica Purkiss
# 4   4  Iranian woman jailed for fictional unpublished...      Howard Portnoy
#
#                                                 text  label
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...      1  \
# 1  Ever get the feeling your life circles the rou...      0
# 2  Why the Truth Might Get You Fired October 29, ...      1
# 3  Videos 15 Civilians Killed In Single US Airstr...      1
# 4  Print \nAn Iranian woman has been sentenced to...      1
#
#                                              content
# 0  Darrell Lucus House Dem Aide: We Didn’t Even S...
# ...

# %% [markdown]
# STEMMING TIME

# %%
porter_stemmer=PorterStemmer()

# %%
def stemming(content):
    stemmed_content = re.sub('[^a-zA-Z]',' ',content)
    stemmed_content = stemmed_content.lower()
    stemmed_content = stemmed_content.split()
    stemmed_content = [porter_stemmer.stem(word) for word in stemmed_content if not word in stopwords.words('english')]
    stemmed_content = ' '.join(stemmed_content)
    return stemmed_content

# %%
txt="hello just died"
txt=stemming(txt)

# %%
df['content']=df['content'].apply(stemming)

# %% [markdown]
# # MODEL BUILDING

# %%
df.head()
# Out:
#    id                                              title              author
# 0   0  House Dem Aide: We Didn’t Even See Comey’s Let...       Darrell Lucus  \
# 1   1  FLYNN: Hillary Clinton, Big Woman on Campus - ...     Daniel J. Flynn
# 2   2                  Why the Truth Might Get You Fired  Consortiumnews.com
# 3   3  15 Civilians Killed In Single US Airstrike Hav...     Jessica Purkiss
# 4   4  Iranian woman jailed for fictional unpublished...      Howard Portnoy
#
#                                                 text  label
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...      1  \
# 1  Ever get the feeling your life circles the rou...      0
# 2  Why the Truth Might Get You Fired October 29, ...      1
# 3  Videos 15 Civilians Killed In Single US Airstr...      1
# 4  Print \nAn Iranian woman has been sentenced to...      1
#
#                                              content
# 0  darrel lucu hous dem aid even see comey letter...
# ...

# %%
x=df['content']
y=df['label']

# %% [markdown]
# # FINALLIZING X

# %%
vectorizer = TfidfVectorizer()

# %%
vectorizer.fit(x)
# Out:
# TfidfVectorizer()

# %%
x=vectorizer.transform(x)

# %%
from sklearn.model_selection import train_test_split
X=x
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=45)

# %%
DecisionTreeClassifier=DecisionTreeClassifier()
# Out:
# ---------------------------------------------
# TypeError   Traceback (most recent call last)
# Cell In[116], line 1
# ----> 1 DecisionTreeClassifier=DecisionTreeClassifier()
#
# TypeError: 'DecisionTreeClassifier' object is not callable

# %%
DecisionTreeClassifier.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=DecisionTreeClassifier.predict(X_test)

# %%
accuracy_score(y_test,y_pred)*100
# Out:
# 99.30288461538461

# %%
precision_score(y_test,y_pred)
# Out:
# 0.9928023032629558

# %%
fake_news = ["Scientists Discover That Moon Is Made of Edible Cheese. "
             "NASA confirms the Moon is composed entirely of cheese, "
             "raising hopes of solving world hunger through lunar mining."]

# %%
tri=stemming(str(fake_news))

# %%
tri
# Out:
# 'scientist discov moon made edibl chees nasa confirm moon compos entir chees rais hope solv world hunger lunar mine'

# %%
tri=vectorizer.transform(fake_news)

# %%
tri
# Out:
# <1x17128 sparse matrix of type '<class 'numpy.float64'>'
# 	with 7 stored elements in Compressed Sparse Row format>

# %%
if(DecisionTreeClassifier.predict(tri)[0]==1):
    print("fake")
# Out:
# fake
